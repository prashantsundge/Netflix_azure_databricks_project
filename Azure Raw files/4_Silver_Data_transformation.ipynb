# %% [markdown]
# # Silver Data Transformation

# %% [markdown]
# ### PULL THE LIBRARISE

# %%
#Pull the libraries 
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = spark.read.format("delta")\
    .option("header", True)\
    .option("inferSchema", True)\
    .load("abfss://bronze@netflixprojectdlpams.dfs.core.windows.net/netflix_titles")

# %%
display(df)

# %% [markdown]
# #### GIT RID OF NULLS

# %%
df = df.fillna({"duration_minutes": 0 , "duration_seasons": 1})

# %%
df.display()

# %%
df.describe().display()

# %%
df.withColumn("duration_minutes", df["duration_minutes"].cast(IntegerType()))
# Out:
# DataFrame[duration_minutes: int, duration_seasons: string, type: string, title: string, date_added: string, release_year: string, rating: string, description: string, show_id: string, _rescued_data: string]

# %%
df.display()

# %% [markdown]
# ### CONVERT DATA TYPES

# %%
df = df.withColumn("duration_minutes", col("duration_minutes").cast(IntegerType()))\
    .withColumn("duration_seasons", col("duration_seasons").cast(IntegerType()))\
    .withColumn("release_year", col("release_year").cast(IntegerType()))\
    .withColumn("date_added" , to_date(col("date_added"), "M/d/yyyy"))\
    .withColumn("type", lower(trim(col("type"))))\
    .withColumn("title", lower(trim(col("title"))))\
    .withColumn("rating", lower(trim(col("rating"))))

# %%
df.printSchema()
# Out:
# root
#  |-- duration_minutes: integer (nullable = true)
#  |-- duration_seasons: integer (nullable = true)
#  |-- type: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- date_added: date (nullable = true)
#  |-- release_year: integer (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- show_id: string (nullable = true)
#  |-- _rescued_data: string (nullable = true)

# %% [markdown]
# #### DROP ROWS WITH MISSING CRITICAL VALUES

# %%
df = df.dropna(subset=["title", "type", "release_year"])

# %%
df.describe().display()

# %%
df.display(5)

# %%
df.select("rating").distinct().show()
# Out:
# +--------+
# |  rating|
# +--------+
# |   tv-14|
# |       g|
# |      ur|
# |   tv-pg|
# |    NULL|
# |tv-y7-fv|
# |      nr|
# |   pg-13|
# |   nc-17|
# |      pg|
# |       r|
# |   tv-ma|
# |    tv-y|
# |    tv-g|
# |   tv-y7|
# +--------+

# %%
# See the count 
df.groupBy("rating").count().orderBy("count", ascending=False).show()
# Out:
# +--------+-----+
# |  rating|count|
# +--------+-----+
# |   tv-ma| 2027|
# |   tv-14| 1698|
# |   tv-pg|  700|
# |       r|  508|
# |   pg-13|  286|
# |      nr|  218|
# |      pg|  184|
# |   tv-y7|  169|
# |    tv-g|  149|
# |    tv-y|  143|
# |tv-y7-fv|   95|
# |       g|   37|
# |    NULL|   11|
# |      ur|    7|
# |   nc-17|    2|
# +--------+-----+

# %%
# See the count 
movies_count_release_year = df.groupBy("release_year").count().orderBy("count", ascending=False)

# %%
movies_count_release_year.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ### REMOVE DUPLICATES

# %%
df = df.dropDuplicates()

# %%
df = df.fillna({"rating": "unknown"})

# %% [markdown]
# ### DROP UNNECESSORY COLUMN

# %%
df = df.drop("_rescued_data")

# %%
df.display(5)

# %% [markdown]
# ### CLEAN WHITESPACE

# %%
df = df.withColumn("description",trim(col("description")))

# %%
df.display(5)

# %% [markdown]
# ### WHEN OTHERWISE

# %%
df = df.withColumn("type_flag", when(col("type") == "movie", 1)\
                                .when(col("type") == "tv show", 2)\
                                .otherwise(0))
display(df)

# %% [markdown]
# ### SQL QUERIES

# %%
# this can be used only on this notebook not for global so we can say this view is only for local this notebook 
df_sql = df.createOrReplaceTempView("temp_view")

# %%
df_sql = spark.sql("""
               SELECT * FROM temp_view
               """)

# %%
df_sql.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>duration_minutes</th><th>duration_seasons</th><th>type</th><th>title</th><th>date_added</th><th>release_year</th><th>rating</th><th>description</th><th>show_id</th><th>type_flag</th></tr></thead><tbody><tr><td>0</td><td>1</td><td>tv show</td><td>forget me not</td><td>2017-09-18</td><td>2011</td><td>tv-ma</td><td>Teenage Xue Ming was forced to marry the man who raped her. Years after abandoning her young sons to find a better life, can she escape the guilt?</td><td>80136785</td><td>2</td></tr><tr><td>97</td><td>1</td><td>movie</td><td>the kindergarten teacher</td><td>2018-10-12</td><td>2018</td><td>r</td><td>A devoted teacher takes interest in a young student's creative potential after hearing his poetry. But she soon crosses the line into obsession.</td><td>80240972</td><td>1</td></tr><tr><td>96</td><td>1</td><td>movie</td><td>walking out</td><td>2019-10-01</td><td>2017</td><td>pg-13</td><td>A suburban teen goes hunting with his estranged father. When a mishap with a bear occurs, he must his use his survival skills to save them both.</td><td>80173150</td><td>1</td></tr><tr><td>129</td><td>1</td><td>movie</td><td>luv shuv tey chicken khurana</td><td>2018-10-01</td><td>2012</td><td>tv-14</td><td>Fleeing London to evade a gangland debt collector, Omi Khurana returns to his native village in India, passing himself off as a successful lawyer.</td><td>70229042</td><td>1</td></tr><tr><td>129</td><td>1</td><td>movie</td><td>phantom</td><td>2018-10-01</td><td>2015</td><td>tv-14</td><td>India's primary intelligence agency sends an enigmatic operative on a top-secret mission to avenge the 11/26 terrorist attack on Mumbai.</td><td>70303495</td><td>1</td></tr><tr><td>107</td><td>1</td><td>movie</td><td>i am bolt</td><td>2017-10-01</td><td>2016</td><td>pg</td><td>Mixing archival footage with present-day interviews, Olympic champion and global icon Usain Bolt opens up about his athletic legacy.</td><td>80135360</td><td>1</td></tr><tr><td>112</td><td>1</td><td>movie</td><td>christmas in the heartland</td><td>2019-11-01</td><td>2017</td><td>tv-pg</td><td>Two girls realize they're both visiting grandparents they’ve never met and decide to switch places to see how the other half lives.</td><td>81063129</td><td>1</td></tr><tr><td>0</td><td>1</td><td>tv show</td><td>kiss the series</td><td>2019-05-26</td><td>2016</td><td>tv-14</td><td>After a night out, Sandee wakes to discover she and her buddy have either taken their platonic friendship to a whole new level or ruined it forever.</td><td>80993756</td><td>2</td></tr><tr><td>93</td><td>1</td><td>movie</td><td>russell madness</td><td>2015-05-10</td><td>2015</td><td>pg</td><td>A spunky terrier named Russell with serious wrestling chops becomes a sports phenomenon with the help of his coach, a monkey named Hunk.</td><td>80028359</td><td>1</td></tr><tr><td>128</td><td>1</td><td>movie</td><td>starting over again</td><td>2019-03-07</td><td>2014</td><td>tv-14</td><td>An architecture student and a history professor fall in love, pursue a dream, split up and bump into each other years later. Can there be a second chance?</td><td>81010865</td><td>1</td></tr><tr><td>99</td><td>1</td><td>movie</td><td>eyyvah eyyvah</td><td>2017-03-10</td><td>2010</td><td>tv-ma</td><td>A clarinet player who lives with his grandparents in a small village is forced to move to Istanbul, where he meets a singer enjoying sudden fame.</td><td>80038353</td><td>1</td></tr><tr><td>173</td><td>1</td><td>movie</td><td>trimurti</td><td>2018-03-01</td><td>1995</td><td>tv-pg</td><td>After being framed, a policewoman languishing in prison hopes that her three sons will deliver justice and restore her honor.</td><td>20717860</td><td>1</td></tr><tr><td>0</td><td>1</td><td>tv show</td><td>the hollow</td><td>2018-06-08</td><td>2018</td><td>tv-y7-fv</td><td>Three teens join forces to find a way home after waking up in a strange re ...

# %%
# we can use global views 
df_sql.createOrReplaceGlobalTempView("global_view")

# %%
df_sql = spark.sql("""
               SELECT * FROM global_temp.global_view
               """)

# %%
df_sql = spark.sql("""
          SELECT rating, COUNT(*) AS count
          FROM global_temp.global_view
          GROUP BY rating
          ORDER BY count DESC 
          """).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rating</th><th>count</th></tr></thead><tbody><tr><td>tv-ma</td><td>2027</td></tr><tr><td>tv-14</td><td>1698</td></tr><tr><td>tv-pg</td><td>700</td></tr><tr><td>r</td><td>508</td></tr><tr><td>pg-13</td><td>286</td></tr><tr><td>nr</td><td>218</td></tr><tr><td>pg</td><td>184</td></tr><tr><td>tv-y7</td><td>169</td></tr><tr><td>tv-g</td><td>149</td></tr><tr><td>tv-y</td><td>143</td></tr><tr><td>tv-y7-fv</td><td>95</td></tr><tr><td>g</td><td>37</td></tr><tr><td>unknown</td><td>11</td></tr><tr><td>ur</td><td>7</td></tr><tr><td>nc-17</td><td>2</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
print(df)
# Out:
# DataFrame[duration_minutes: int, duration_seasons: int, type: string, title: string, date_added: date, release_year: int, rating: string, description: string, show_id: string, type_flag: int]

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .option("path", "abfs://silver@netflixprojectdlpams.dfs.core.windows.net/netflix_titles")\
    .save()
